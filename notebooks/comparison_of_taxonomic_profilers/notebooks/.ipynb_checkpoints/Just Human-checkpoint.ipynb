# %%
import warnings
warnings.filterwarnings('ignore')

# %load_ext rpy2.ipython

# %run ../notebook-init.py

# load R libraries                                                                                    
# %R invisible(library(ggplot2))
# %R invisible(library(fastcluster))
# %R invisible(library(reshape))
# %R invisible(library(reshape2))
# %R invisible(library(gplots))
# %R invisible(library(RSQLite))

#set up ggplot2 defaults                                                                              
# %R theme_set(theme_gray(base_size=18))

# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 20)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%R
# prettyname <- function(ugly){
#     names = c(
#         'gpigfecal.dna',
#         'filtered.stool.day0',
#         'filtered.stool.day14',
#         'rumen.rnalow',
#         'rumen.rnahigh',
#         'cowrumen.dna',
#         'human.anterior.nares',
#         'human.stool',
#         'human.posterior.fornix',
#         'human.throat',
#         'human.qin.CD',
#         'human.qin.HEALTHY',
#         'human.qin.UC'
#
#     )
#
#     classes = c(
#         'Guinea Pig Stool DNA',
#         'Healthy Mouse Stool RNA',
#         'Colitic Mouse Stool RNA',
#         'Sheep Rumen, low-methane prod. RNA',
#         'Sheep Rumen, high-methane prod. RNA',
#         'Cow Rumen DNA',
#         'HMP Anterior Nares DNA',
#         'HMP Stool DNA',
#         'HMP Posterior Fornix DNA',
#         'HMP Throat DNA',
#         'CD Human Stool, Qin et al DNA',
#         'Healthy Human Stool, Qin et al DNA',
#         'UC Human Stool, Qin et al DNA'
#     )
#
#     ougly <- ugly
#     ugly <- strsplit(ugly,c("[\\_\\.\\-]"),fixed=F)[[1]]
#
#
#     i <- 1
#     for (name in names){
#
#
#         name <- strsplit(name,c("[\\_\\.\\-]"),fixed=F)[[1]]
#
#         if( all(ugly==name)){
#             return( classes[i])
#         }
#         i <- i+1
#     }
#     return(ougly)
#
# }
#
# print(prettyname("gpigfecal.dna"))
# print(prettyname("human.posterior_fornix"))
# print(prettyname("cowrumen.dna"))
# print(prettyname("human.anterior_nares"))
# Out:
# [1] "Guinea Pig Stool DNA"
# [1] "HMP Posterior Fornix DNA"
# [1] "Cow Rumen DNA"
# [1] "HMP Anterior Nares DNA"

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # KRAKEN
# #
# ##########################################################
# ##########################################################
#
#
# tableNames <- Sys.glob('../taxonomic-profiles/kraken/*.species.kraken.aggregated.counts.tsv.gz')
# print(tableNames)
#
# k.classes <- c()
# kraken <- matrix(0,0,0)
# k.raw <- matrix(0,0,0)
# for (tbl in tableNames){
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     classesInTbl <- lapply(colnames(tbl),function(n){prettyname(strsplit(n,'\\.R')[[1]][1])})
#
#     tbl[is.na(tbl)] <- 0
#
#     k.raw <- merge(k.raw,tbl,by="row.names",all=T)
#     k.raw[is.na(k.raw)] <- 0
#     rownames(k.raw) <- k.raw[,1]
#     k.raw <- k.raw[,-1]
#
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     k.classes <- c(k.classes,  unlist(classesInTbl))
#     kraken <- merge(kraken,tbl,by="row.names",all=T)
#     kraken[is.na(kraken)] <- 0
#     rownames(kraken) <- kraken[,1]
#     kraken <- kraken[,-1]
# }
# k.classes <- as.factor(k.classes)
# print(k.classes)
# print(kraken[1:2,1:4])
# kraken <- kraken[apply(kraken, 1, function(row) any(row !=0 )),]
#
# k.pca <- prcomp(t(kraken),center=T,scale=T)
# plot(k.pca,type='l')
# Out:
# [1] "../taxonomic-profiles/kraken/cow_rumen.species.kraken.aggregated.counts.tsv.gz"
# [2] "../taxonomic-profiles/kraken/g_pig.species.kraken.aggregated.counts.tsv.gz"
# [3] "../taxonomic-profiles/kraken/human_qin.species.kraken.aggregated.counts.tsv.gz"
# [4] "../taxonomic-profiles/kraken/human.species.kraken.aggregated.counts.tsv.gz"
# [5] "../taxonomic-profiles/kraken/sheep_rumen.species.kraken.aggregated.counts.tsv.gz"
#  [1] Cow Rumen DNA                       Cow Rumen DNA
#  [3] Cow Rumen DNA                       Cow Rumen DNA
#  [5] Cow Rumen DNA                       Cow Rumen DNA
#  [7] Cow Rumen DNA                       Cow Rumen DNA
#  [9] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [11] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [13] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [15] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [17] CD Human Stool, Qin et al DNA       CD Human Stool, Qin et al DNA
# [19] CD Human Stool, Qin et al DNA       CD Human Stool, Qin et al DNA
# [21] CD Human Stool, Qin et al DNA       CD Human Stool, Qin et al DNA
# [23] Healthy Human Stool, Qin et al DNA  Healthy Human Stool, Qin et al DNA
# [25] Healthy Human Stool, Qin et al DNA  Healthy Human Stool, Qin et al DNA
# [27] Healthy Human Stool, Qin et al DNA  Healthy Human Stool, Qin et al DNA
# [29] UC Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
# [31] UC Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
# [33] UC Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
# [35] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [37] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [39] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [41] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [43] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [45] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [47] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [49] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [51] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [53] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [55] HMP Stool DNA                       HMP Stool DNA
# [57] HMP Stool DNA                       HMP Stool DNA
# [59] HMP Stool DNA                       HMP Stool DNA
# [61] HMP Stool DNA                       HMP Stool DNA
# [63] HMP Stool DNA                       HMP Stool DNA
# [65] HMP Throat DNA                      HMP Throat DNA
# [67] HMP Throat DNA                      HMP Throat DNA
# [69] HMP Throat DNA                      HMP Throat DNA
# [71] HMP Throat DNA                      Sheep Rumen, high-methane prod. RNA
# [73] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [75] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [77] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [79] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [81] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [83] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [85] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# 11 Levels: CD Human Stool, Qin et al DNA Cow Rumen DNA ... UC Human Stool, Qin et al DNA
#                                       cowrumen.dna.R983262.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                2.828752
# Acanthamoeba_polyphaga_mimivirus                                                     6.916215
#                                       cowrumen.dna.R983263.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                2.735725
# Acanthamoeba_polyphaga_mimivirus                                                     5.543080
#                                       cowrumen.dna.R983264.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                0.000000
# Acanthamoeba_polyphaga_mimivirus                                                     2.612435
#                                       cowrumen.dna.R983265.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                               0.7787663
# Acanthamoeba_polyphaga_mimivirus                                                    7.6856569

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # METAPHLAN2
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('../taxonomic-profiles/metaphlan/*.mp2prof.tsv')
#
# m.classes <- c()
# mphlan <- matrix(0,0,0)
#
# getTable <- function(tblName){
#     out <- tryCatch(
#         {
#             tbl <- read.table(tblName,blank.lines.skip=T,sep="\t",row.names=1)
#             return(tbl)
#         },
#         error=function(cond){
#             return(FALSE)
#         },
#         warning=function(cond){
#             return(FALSE)
#         },
#         finally={
#
#         }
#     )
#     return(out)
# }
#
#
# for (tblName in tableNames){
#     print(tblName)
#     tbl <- getTable(tblName)
#     if(!tbl){
#         next
#     }
#
#     class <- tail(strsplit(strsplit(tblName,'-R')[[1]][1],'/')[[1]],1)
#     class <- tail(strsplit(class,'\\.')[[1]],1)
#     class <- prettyname(class)
#     sample <- tail(strsplit(strsplit(tblName,'\\.mp2')[[1]][1],'/')[[1]],1)
#     genera <- rownames(tbl)[grep('g__',rownames(tbl))]
#     genera <- genera[grep('s__',genera,invert=T)]
#     tbl <-tbl[rownames(tbl) %in% genera,,drop=F]
#     m.classes <- c(m.classes,class)
#     newcolnames <- c(colnames(mphlan),sample)
#     mphlan <- merge(mphlan,tbl,by="row.names",all=T)
#     mphlan[is.na(mphlan)] <- 0
#     rownames(mphlan) <- mphlan[,1]
#     mphlan <- mphlan[,-1,drop=F]
#     colnames(mphlan) <- newcolnames
# }
# m.classes <- factor(m.classes)
# print(m.classes)
# print(mphlan[1:5,1:4])
#
# m.pca <- prcomp(t(mphlan),center=T,scale=T)
# plot(m.pca,type='l')
# Out:
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983262.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983263.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983264.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983265.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983266.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983267.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983268.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/cow_rumen.cowrumen-dna-R983269.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R495409.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496625.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496626.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496699.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496700.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496701.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496702.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/g_pig.gpigfecal-dna-R496703.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R011132.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R012663.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R014464.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R014901.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R015996.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R018981.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R022129.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R046973.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R050025.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-anterior_nares-R056210.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R011355.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R011584.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R012294.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R014343.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R018769.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R024068.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R044742.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R048536.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R057807.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-posterior_fornix-R064704.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011061.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011084.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011134.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011239.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011271.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011302.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011405.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011452.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011529.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-stool-R011586.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R013948.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R014475.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R014689.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R015062.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R019027.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R019127.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human.human-throat-R065335.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R14.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R15.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R1.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R4.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R8.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-CD-R9.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R01.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R03.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R04.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R06.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R16.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-HEALTHY-R20.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R11.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R14.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R18.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R1.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R20.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/human_qin.human_qin-UC-R23.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R1.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R2.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R3.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R4.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R5.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R6.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R7.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day0-R8.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R1.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R2.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R3.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R4.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R5.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R6.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R7.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/mouse.filtered.stool-day14-R8.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873459.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873460.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873461.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873462.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873463.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873464.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnahigh-R873465.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873450.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873451.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873452.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873453.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873454.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873455.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873456.mp2prof.tsv"
# [1] "../taxonomic-profiles/metaphlan/sheep_rumen.rumen-rnalow-R873457.mp2prof.tsv"
#  [1] Cow Rumen DNA                       Cow Rumen DNA
#  [3] Cow Rumen DNA                       Cow Rumen DNA
#  [5] Cow Rumen DNA                       Cow Rumen DNA
#  [7] Cow Rumen DNA                       Cow Rumen DNA
#  [9] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [11] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [13] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [15] Guinea Pig Stool DNA                Guinea Pig Stool DNA
# [17] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [19] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [21] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [23] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [25] HMP Anterior Nares DNA              HMP Anterior Nares DNA
# [27] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [29] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [31] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [33] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [35] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
# [37] HMP Stool DNA                       HMP Stool DNA
# [39] HMP Stool DNA                       HMP Stool DNA
# [41] HMP Stool DNA                       HMP Stool DNA
# [43] HMP Stool DNA                       HMP Stool DNA
# [45] HMP Stool DNA                       HMP Stool DNA
# [47] HMP Throat DNA                      HMP Throat DNA
# [49] HMP Throat DNA                      HMP Throat DNA
# [51] HMP Throat DNA                      HMP Throat DNA
# [53] HMP Throat DNA                      CD Human Stool, Qin et al DNA
# [55] CD Human Stool, Qin et al DNA       Healthy Human Stool, Qin et al DNA
# [57] Healthy Human Stool, Qin et al DNA  Healthy Human Stool, Qin et al DNA
# [59] UC Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
# [61] UC Human Stool, Qin et al DNA       stool-day0
# [63] stool-day0                          stool-day0
# [65] stool-day0                          stool-day0
# [67] stool-day0                          stool-day0
# [69] stool-day0                          stool-day14
# [71] stool-day14                         stool-day14
# [73] stool-day14                         stool-day14
# [75] stool-day14                         stool-day14
# [77] stool-day14                         Sheep Rumen, high-methane prod. RNA
# [79] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [81] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [83] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
# [85] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [87] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [89] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [91] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# 13 Levels: CD Human Stool, Qin et al DNA Cow Rumen DNA ... UC Human Stool, Qin et al DNA
#                                                                                                                               cow_rumen.cowrumen-dna-R983262
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                                   12.46866
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified                        0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Actinomycetaceae|g__Actinomyces                                                0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                            0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Corynebacteriaceae|g__Corynebacterium                                          0.00000
#                                                                                                                               cow_rumen.cowrumen-dna-R983263
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                                   22.56221
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified                        0.02308
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Actinomycetaceae|g__Actinomyces                                                0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                            0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Corynebacteriaceae|g__Corynebacterium                                          0.00000
#                                                                                                                               cow_rumen.cowrumen-dna-R983264
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                                    8.02903
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified                        0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Actinomycetaceae|g__Actinomyces                                                0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                            0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Corynebacteriaceae|g__Corynebacterium                                          0.00000
#                                                                                                                               cow_rumen.cowrumen-dna-R983265
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                                   47.32666
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified                        0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Actinomycetaceae|g__Actinomyces                                                0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                            0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Corynebacteriaceae|g__Corynebacterium                                          0.00000

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # AC-DIAMOND FAST
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('../taxonomic-profiles/ac-diamond-fast/*.species.*dmndfast.aggregated.counts.tsv.gz')
# print(tableNames)
#
# adf.classes <- c()
# acdmndfast <- matrix(0,0,0)
# adf.raw <- matrix(0,0,0)
# for (tbl in tableNames){
#     print(tbl)
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     classesInTbl <- lapply(colnames(tbl),function(n){prettyname(strsplit(n,'\\.R')[[1]][1])})
#
#     adf.raw <- merge(adf.raw,tbl,by="row.names",all=T)
#     adf.raw[is.na(adf.raw)] <- 0
#     rownames(adf.raw) <- adf.raw[,1]
#     adf.raw <- adf.raw[,-1]
#
#     tbl[is.na(tbl)] <- 0
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     adf.classes <- c(adf.classes,  unlist(classesInTbl))
#     acdmndfast <- merge(acdmndfast,tbl,by="row.names",all=T)
#     acdmndfast[is.na(acdmndfast)] <- 0
#
#     rownames(acdmndfast) <- acdmndfast[,1]
#     acdmndfast <- acdmndfast[,-1]
# }
# adf.classes <- factor(adf.classes)
# print(adf.classes)
# acdmndfast <- acdmndfast[apply(acdmndfast, 1, function(row) any(row !=0 )),]
#
# print(length(adf.classes))
# print(dim(acdmndfast))
# print(acdmndfast[1:5,1:4])
#
#
# adf.pca <- prcomp(t(acdmndfast),center=T,scale=T)
# plot(adf.pca,type='l')
# Out:
# [1] "../taxonomic-profiles/ac-diamond-fast/cow_rumen.species.dmndfast.aggregated.counts.tsv.gz"
# [2] "../taxonomic-profiles/ac-diamond-fast/g_pig.species.acdmndfast.aggregated.counts.tsv.gz"
# [3] "../taxonomic-profiles/ac-diamond-fast/hmp.species.acdmndfast.aggregated.counts.tsv.gz"
# [4] "../taxonomic-profiles/ac-diamond-fast/human_qin.species.acdmndfast.aggregated.counts.tsv.gz"
# [5] "../taxonomic-profiles/ac-diamond-fast/mouse.species.acdmndfast.aggregated.counts.tsv.gz"
# [6] "../taxonomic-profiles/ac-diamond-fast/sheep_rumen.species.acdmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/cow_rumen.species.dmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/g_pig.species.acdmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/hmp.species.acdmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/human_qin.species.acdmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/mouse.species.acdmndfast.aggregated.counts.tsv.gz"
# [1] "../taxonomic-profiles/ac-diamond-fast/sheep_rumen.species.acdmndfast.aggregated.counts.tsv.gz"
#   [1] Cow Rumen DNA                       Cow Rumen DNA
#   [3] Cow Rumen DNA                       Cow Rumen DNA
#   [5] Cow Rumen DNA                       Cow Rumen DNA
#   [7] Cow Rumen DNA                       Cow Rumen DNA
#   [9] Guinea Pig Stool DNA                Guinea Pig Stool DNA
#  [11] Guinea Pig Stool DNA                Guinea Pig Stool DNA
#  [13] Guinea Pig Stool DNA                Guinea Pig Stool DNA
#  [15] Guinea Pig Stool DNA                Guinea Pig Stool DNA
#  [17] HMP Posterior Fornix DNA            HMP Anterior Nares DNA
#  [19] HMP Posterior Fornix DNA            HMP Stool DNA
#  [21] HMP Throat DNA                      HMP Throat DNA
#  [23] HMP Stool DNA                       HMP Throat DNA
#  [25] HMP Anterior Nares DNA              HMP Stool DNA
#  [27] HMP Throat DNA                      HMP Throat DNA
#  [29] HMP Posterior Fornix DNA            HMP Stool DNA
#  [31] HMP Anterior Nares DNA              HMP Anterior Nares DNA
#  [33] HMP Posterior Fornix DNA            HMP Anterior Nares DNA
#  [35] HMP Stool DNA                       HMP Stool DNA
#  [37] HMP Posterior Fornix DNA            HMP Anterior Nares DNA
#  [39] HMP Stool DNA                       HMP Anterior Nares DNA
#  [41] HMP Stool DNA                       HMP Anterior Nares DNA
#  [43] HMP Anterior Nares DNA              HMP Stool DNA
#  [45] HMP Throat DNA                      HMP Stool DNA
#  [47] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
#  [49] HMP Posterior Fornix DNA            HMP Throat DNA
#  [51] HMP Posterior Fornix DNA            HMP Posterior Fornix DNA
#  [53] HMP Anterior Nares DNA              UC Human Stool, Qin et al DNA
#  [55] UC Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
#  [57] Healthy Human Stool, Qin et al DNA  CD Human Stool, Qin et al DNA
#  [59] CD Human Stool, Qin et al DNA       Healthy Human Stool, Qin et al DNA
#  [61] CD Human Stool, Qin et al DNA       CD Human Stool, Qin et al DNA
#  [63] UC Human Stool, Qin et al DNA       Healthy Human Stool, Qin et al DNA
#  [65] CD Human Stool, Qin et al DNA       Healthy Human Stool, Qin et al DNA
#  [67] CD Human Stool, Qin et al DNA       UC Human Stool, Qin et al DNA
#  [69] UC Human Stool, Qin et al DNA       Healthy Human Stool, Qin et al DNA
#  [71] Healthy Human Stool, Qin et al DNA  Colitic Mouse Stool RNA
#  [73] Healthy Mouse Stool RNA             Healthy Mouse Stool RNA
#  [75] Colitic Mouse Stool RNA             Healthy Mouse Stool RNA
#  [77] Healthy Mouse Stool RNA             Colitic Mouse Stool RNA
#  [79] Healthy Mouse Stool RNA             Healthy Mouse Stool RNA
#  [81] Healthy Mouse Stool RNA             Colitic Mouse Stool RNA
#  [83] Colitic Mouse Stool RNA             Colitic Mouse Stool RNA
#  [85] Colitic Mouse Stool RNA             Colitic Mouse Stool RNA
#  [87] Healthy Mouse Stool RNA             Sheep Rumen, high-methane prod. RNA
#  [89] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, high-methane prod. RNA
#  [91] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
#  [93] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, high-methane prod. RNA
#  [95] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, high-methane prod. RNA
#  [97] Sheep Rumen, high-methane prod. RNA Sheep Rumen, high-methane prod. RNA
#  [99] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, low-methane prod. RNA
# [101] Sheep Rumen, low-methane prod. RNA  Sheep Rumen, high-methane prod. RNA
# 13 Levels: CD Human Stool, Qin et al DNA ... UC Human Stool, Qin et al DNA
# [1] 102
# [1] 5652  102
#                                          cowrumen.dna.R983268_count
# Abiotrophia_defectiva                                    0.00000000
# Abiotrophia_para-adiacens                                0.00000000
# Acanthamoeba_castellanii_mamavirus                       0.04119719
# Acanthamoeba_polyphaga_mimivirus                         0.00000000
# Acanthocystis_turfacea_Chlorella_virus_1                 0.00000000
#                                          cowrumen.dna.R983267_count
# Abiotrophia_defectiva                                      0.000000
# Abiotrophia_para-adiacens                                  0.000000
# Acanthamoeba_castellanii_mamavirus                         2.274195
# Acanthamoeba_polyphaga_mimivirus                           0.000000
# Acanthocystis_turfacea_Chlorella_virus_1                   0.000000
#                                          cowrumen.dna.R983263_count
# Abiotrophia_defectiva                                      0.000000
# Abiotrophia_para-adiacens                                  0.000000
# Acanthamoeba_castellanii_mamavirus                         1.188136
# Acanthamoeba_polyphaga_mimivirus                           0.000000
# Acanthocystis_turfacea_Chlorella_virus_1                   0.000000
#                                          cowrumen.dna.R983266_count
# Abiotrophia_defectiva                                             0
# Abiotrophia_para-adiacens                                         0
# Acanthamoeba_castellanii_mamavirus                                0
# Acanthamoeba_polyphaga_mimivirus                                  0
# Acanthocystis_turfacea_Chlorella_virus_1                          0

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # PCA Plots
# #
# ##########################################################
# ##########################################################
#
# library(ggplot2)
# library(gridExtra)
# library(factoextra)
#
# plotPCA <- function(comps, pca, classes){
#
#         df <- data.frame(pca$x)
#         df['Groups'] = classes
#         combs <- combn(comps,2,simplify=F)
#         for (comb in combs){
#             X = colnames(df)[comb[1]]
#             Y = colnames(df)[comb[2]]
#             p <- ggplot(df,aes_string(x=X,y=Y, color="Groups")) +
#                     geom_point(size=4) +
#                     scale_shape_manual(values=c(3,16,17)) +
#                     stat_ellipse(geom = "polygon", alpha = 1/10,aes_string(fill="Groups")) +
#                     theme_minimal()
#             print(p)
#         }
#
# }

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # ICA Plots
# #
# ##########################################################
# ##########################################################
#
# library(ggplot2)
# library(gridExtra)
# library(factoextra)
#
# plotICA <- function(ica, classes){
#
#     df <- data.frame(ica$S)
#     df['Groups'] = classes
#     combs <- combn(1:dim(ica$S)[2],2,simplify=F)
#     for (comb in combs){
#         X = colnames(df)[comb[1]]
#         Y = colnames(df)[comb[2]]
#         p <- ggplot(df,aes_string(x=X,y=Y, color="Groups")) +
#                 geom_point(size=4) +
#                 stat_ellipse(geom = "polygon", alpha = 1/10,aes_string(fill="Groups")) +
#                 theme_minimal()
#         print(p)
#     }
# }

# %%
# %%R
#
# plotPCA(1:4, adf.pca, adf.classes)

# %%
# %%R
# plotPCA(1:4, k.pca, k.classes)

# %%
# %%R
# plotPCA(1:4, m.pca, m.classes)

# %%
# %%R
#
#
# make_jsd_matrix <- function(n){
#
#     m <- matrix(nrow=ncol(n),ncol=ncol(n))
#
#     for (i in 1:ncol(n)){
#         for (j in 1:ncol(n)){
#             m[i,j] <- jsd(n[,i],n[,j])
#         }
#      }
#     colnames(m) <- colnames(n)
#      rownames(m) <- colnames(n)
#      return(m)
# }
#
# jsd <- function(a,b){
#     anorm <- a/sum(a)
#     bnorm <- b/sum(b)
#      m <- (anorm+bnorm)/2
#      div <- kld(anorm,m)/2 + kld(bnorm,m)/2
#      dist <- sqrt(div)
#      return(dist)
# }
#
# kld <- function(a,b){
#      l <- log(a/b, 2)
#      l[is.na(l)] <- 0
#      l[is.infinite(l)] <- 0
#
#     return( sum( a * l))
# }

# %%
# %%R
#
# library(devtools)
# library(reshape2)
# library(Heatplus)
# library(RColorBrewer)
# library(gplots)
# source('../custom-code/heatmap.3.by-obi-griffith.R')
#
# as_species <- function(n){
#     species <- c(
#                     "Cow",
#                     "Mouse",
#                     "Human",
#                     "Sheep",
#                     "G. Pig"
#                 )
#     if(n == 'Guinea Pig Stool DNA'){
#         return("G. Pig")
#     } else if("HMP" %in% strsplit(n," ")[[1]]){
#         return("Human")
#     }
#     for (s in species){
#         if( s %in% strsplit(n," ")[[1]]){
#             return(s)
#         }
#     }
#
#     if("stool" %in% strsplit(n,"-")[[1]]){
#         return("Mouse")
#     }
#     print(n)
#     return(n)
# }
#
# my_plot_heatmap <- function(m,classes){
#
#     cCols <- rainbow(length(unique(classes)),s=0.4)[unclass(classes)]
#     species <- as.factor(unlist(lapply(as.character(classes),FUN=as_species)))
#     sCols <- rainbow(length(unique(species)))[unclass(species)]
#
#     sideCols <- cbind(cCols,sCols)
#     colnames(sideCols) <- c("Experiment", "Species")
#         mydist=function(c) {dist(c,method="euclidian")}
#         myclust=function(c) {hclust(c,method="average")}
#         heatmap.3(m,
#                     scale="none",
#                     hclustfun=myclust,
#                     distfun=mydist,
#                     ColSideColors=sideCols,
#                       ColSideColorsSize=3,
#                     nrow=2,
#                     labRow=FALSE,
#                     labCol=FALSE,
#                     margins=c(6,12),
#                     key=FALSE,
#                     dendrogram="row"
#                     )
#
#             legend("topleft",
#                ncol=2,
#                legend=as.character(unique(species)),
#                fill=unique(sCols),
#                border=FALSE,
#                bty="n",
#                cex=1,
#                y.intersp=0.7,
#               )
#
# }

# %%
# %%R -w 720 -h 720 -u px
# adf.jdm <- make_jsd_matrix(acdmndfast)
#
# my_plot_heatmap(adf.jdm, adf.classes)

# %%
# %%R -w 720 -h 720 -u px
#
# m.jdm <- make_jsd_matrix(mphlan)
# my_plot_heatmap(m.jdm,m.classes)

# %%
# %%R -w 720 -h 720 -u px
#
# k.jdm <- make_jsd_matrix(kraken)
# my_plot_heatmap(k.jdm,k.classes)

# %%
# %%R -w 960 -h 720 -u px
# dim(k.raw)
#
# #########################################################################################
# #########################################################################################
# #
# # Richness Figure
# #
# #########################################################################################
# #########################################################################################
#
# getrichness <- function(vec){
#    return(sum(vec!=0))
# }
#
# getshannon <- function(vec){
#     colsum = sum(vec)
#     ps <- lapply(vec,FUN=function(el){
#         p = 0.0000001 + el / colsum
#         return( p * log(p))
#     })
#     ps <- unlist(ps)
#     return(-sum(ps))
# }
#
# getsimpson <- function(vec){
#     colsum = sum(vec)
#     ps <- lapply(vec,FUN=function(el){
#         p = 0.0000001 + el / colsum
#         return( p * p)
#     })
#     ps <- unlist(ps)
#     return(1-sum(ps))
# }
#
# k.richness <- apply(k.raw,2,getrichness)
# adf.richness <- apply(adf.raw,2,getrichness)
#
# k.shannon <- apply(k.raw,2,getshannon)
# adf.shannon <- apply(adf.raw,2,getshannon)
# adf.shannon.limited <- apply(adf.raw[rownames(adf.raw) %in% rownames(k.raw),],2,getshannon)
#
# k.simpson <- apply(k.raw,2,getsimpson)
# adf.simpson <- apply(adf.raw,2,getsimpson)
#
# my_boxplot <- function(stat, groups){
#     o <- order(richness)
#     rtable <- data.frame(x=stat[o], grp=groups[o])
# #     print(head(rtable))
#     ggplot(rtable,aes(x=grp,y=x,color=grp)) +
#         geom_point() +
#         geom_boxplot() +
#         geom_jitter() +
#         scale_y_log10()+
#         theme_minimal() +
#         theme(axis.text.x = element_blank(),legend.position="bottom")
# }
#
# #print(my_boxplot(k.richness,k.classes))
# #print(my_boxplot(adf.richness,adf.classes))
#
# shared.classes <- intersect( unique(adf.classes), unique(k.classes))
# k.richness.shared <- k.richness[k.classes %in% shared.classes]
# adf.richness.shared <- adf.richness[adf.classes %in% shared.classes]
#
# shared.classes <- adf.classes[adf.classes %in% shared.classes]
# rtable <- data.frame(group=shared.classes, diamond=adf.richness.shared, kraken=k.richness.shared)
# rtable <- melt(rtable,id.vars=1)
# rplot <- ggplot(rtable,aes(x=group,y=value,fill=variable)) +
#         geom_boxplot(alpha=0.4) +
#         geom_point(position=position_jitterdodge(),size=2) +
#         scale_y_log10()+
#         theme_minimal() +
#         ylab("Num. Species (log scale)") +
#         theme(axis.text.x = element_text(angle = 45, hjust = 1),axis.title.x=element_blank(),legend.position="bottom") +
#         scale_fill_discrete("Tool")
#
# shared.classes <- intersect( unique(adf.classes), unique(k.classes))
# k.shannon.shared <- k.shannon[k.classes %in% shared.classes]
# adf.shannon.shared <- adf.shannon[adf.classes %in% shared.classes]
# adf.shannon.limited.shared <- adf.shannon.limited[adf.classes %in% shared.classes]
# shared.classes <- adf.classes[adf.classes %in% shared.classes]
# #rtable <- data.frame(group=shared.classes, diamond=adf.shannon.shared, diamond.limited=adf.shannon.limited.shared, kraken=k.shannon.shared)
# rtable <- data.frame(group=shared.classes, diamond=adf.shannon.shared, kraken=k.shannon.shared)
# rtable <- melt(rtable,id.vars=1)
# splot <- ggplot(rtable,aes(x=group,y=value,fill=variable)) +
#         geom_boxplot(alpha=0.4) +
#         geom_point(position=position_jitterdodge(),size=2) +
#         theme_minimal() +
#         ylab("Shannon Index") +
#         theme(axis.text.x =element_blank(),axis.title.x=element_blank(), legend.position="none")
#
# shared.classes <- intersect( unique(adf.classes), unique(k.classes))
# k.simpson.shared <- k.simpson[k.classes %in% shared.classes]
# adf.simpson.shared <- adf.simpson[adf.classes %in% shared.classes]
# shared.classes <- adf.classes[adf.classes %in% shared.classes]
# rtable <- data.frame(group=shared.classes, diamond=adf.simpson.shared, kraken=k.simpson.shared)
# rtable <- melt(rtable,id.vars=1)
# homerplot <- ggplot(rtable,aes(x=group,y=value,fill=variable)) +
#         geom_boxplot(alpha=0.4) +
#         geom_point(position=position_jitterdodge(),size=2) +
#         theme_minimal() +
#         ylab("Gini-Simpson Index") +
#         theme(axis.text.x =element_blank(),axis.title.x=element_blank(), legend.position="none") +
#         scale_fill_discrete("Tool")
#
# #print(splot)
# #print(homerplot)
# #print(rplot)
#
# grid.arrange(splot,rplot,ncol=1, heights=c(0.35,0.65))
