# %%
import warnings
warnings.filterwarnings('ignore')

# %load_ext rpy2.ipython

# %run /gfs/devel/ddanko/notebook-init.py

# load R libraries                                                                                    
# %R invisible(library(ggplot2))
# %R invisible(library(fastcluster))
# %R invisible(library(reshape))
# %R invisible(library(reshape2))
# %R invisible(library(gplots))
# %R invisible(library(RSQLite))

#set up ggplot2 defaults                                                                              
# %R theme_set(theme_gray(base_size=18))

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # KRAKEN
# #
# ##########################################################
# ##########################################################
#
#
# tableNames <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/kraken.dir/species.kraken.aggregated.counts.tsv.gz')
# print(tableNames)
#
# k.classes <- c()
# kraken <- matrix(0,0,0)
# for (tbl in tableNames){
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     classesInTbl <- lapply(colnames(tbl),function(n){strsplit(n,'\\.R')[[1]][1]})
#
#     tbl[is.na(tbl)] <- 0
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     k.classes <- c(k.classes,  unlist(classesInTbl))
#     kraken <- merge(kraken,tbl,by="row.names",all=T)
#     kraken[is.na(kraken)] <- 0
#     rownames(kraken) <- kraken[,1]
#     kraken <- kraken[,-1]
# }
# k.classes <- as.factor(k.classes)
# print(k.classes)
# print(kraken[1:2,1:4])
#
# k.pca <- prcomp(t(kraken),center=T,scale=T)
# plot(k.pca,type='l')
# Out:
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/kraken.dir/species.kraken.aggregated.counts.tsv.gz"
# [2] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/kraken.dir/species.kraken.aggregated.counts.tsv.gz"
# [3] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/human/kraken.dir/species.kraken.aggregated.counts.tsv.gz"
#  [1] cowrumen.dna           cowrumen.dna           cowrumen.dna
#  [4] cowrumen.dna           cowrumen.dna           cowrumen.dna
#  [7] cowrumen.dna           cowrumen.dna           gpigfecal.dna
# [10] gpigfecal.dna          gpigfecal.dna          gpigfecal.dna
# [13] gpigfecal.dna          gpigfecal.dna          gpigfecal.dna
# [16] gpigfecal.dna          human.anterior_nares   human.anterior_nares
# [19] human.anterior_nares   human.anterior_nares   human.anterior_nares
# [22] human.anterior_nares   human.anterior_nares   human.anterior_nares
# [25] human.anterior_nares   human.anterior_nares   human.posterior_fornix
# [28] human.posterior_fornix human.posterior_fornix human.posterior_fornix
# [31] human.posterior_fornix human.posterior_fornix human.posterior_fornix
# [34] human.posterior_fornix human.posterior_fornix human.posterior_fornix
# [37] human.stool            human.stool            human.stool
# [40] human.stool            human.stool            human.stool
# [43] human.stool            human.stool            human.stool
# [46] human.stool            human.throat           human.throat
# [49] human.throat           human.throat           human.throat
# [52] human.throat           human.throat
# 6 Levels: cowrumen.dna gpigfecal.dna ... human.throat
#                                       cowrumen.dna.R983262.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                2.828752
# Acanthamoeba_polyphaga_mimivirus                                                     6.916215
#                                       cowrumen.dna.R983263.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                2.735725
# Acanthamoeba_polyphaga_mimivirus                                                     5.543080
#                                       cowrumen.dna.R983264.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                                0.000000
# Acanthamoeba_polyphaga_mimivirus                                                     2.612435
#                                       cowrumen.dna.R983265.species.kraken.counts.tsv.gz_count
# Abalone_herpesvirus_Victoria/AUS/2009                                               0.7787663
# Acanthamoeba_polyphaga_mimivirus                                                    7.6856569
# Error in prcomp.default(t(kraken), center = T, scale = T) :
#   cannot rescale a constant/zero column to unit variance

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # AC-DIAMOND FAST
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/*dmndfast.dir/species.*dmndfast.aggregated.counts.tsv.gz')
# print(tableNames)
#
# adf.classes <- c()
# acdmndfast <- matrix(0,0,0)
# for (tbl in tableNames){
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     classesInTbl <- lapply(colnames(tbl),function(n){strsplit(n,'\\.R')[[1]][1]})
#
#     tbl[is.na(tbl)] <- 0
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     adf.classes <- c(adf.classes,  unlist(classesInTbl))
#     acdmndfast <- merge(acdmndfast,tbl,by="row.names",all=T)
#     acdmndfast[is.na(acdmndfast)] <- 0
#
#     rownames(acdmndfast) <- acdmndfast[,1]
#     acdmndfast <- acdmndfast[,-1]
# }
# adf.classes <- factor(adf.classes)
# print(adf.classes)
#
# print(length(adf.classes))
# print(dim(acdmndfast))
# print(acdmndfast[1:5,1:4])
#
#
# adf.pca <- prcomp(t(acdmndfast),center=T,scale=T)
# plot(adf.pca,type='l')
# Out:
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmndfast.dir/species.acdmndfast.aggregated.counts.tsv.gz"
# [2] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/mouse/acdmndfast.dir/species.acdmndfast.aggregated.counts.tsv.gz"
# [3] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/sheep_rumen/acdmndfast.dir/species.acdmndfast.aggregated.counts.tsv.gz"
#  [1] gpigfecal.dna        gpigfecal.dna        gpigfecal.dna
#  [4] gpigfecal.dna        gpigfecal.dna        gpigfecal.dna
#  [7] gpigfecal.dna        gpigfecal.dna        filtered.stool.day14
# [10] filtered.stool.day0  filtered.stool.day0  filtered.stool.day14
# [13] filtered.stool.day0  filtered.stool.day0  filtered.stool.day14
# [16] filtered.stool.day0  filtered.stool.day0  filtered.stool.day0
# [19] filtered.stool.day14 filtered.stool.day14 filtered.stool.day14
# [22] filtered.stool.day14 filtered.stool.day14 filtered.stool.day0
# [25] rumen.rnahigh        rumen.rnalow         rumen.rnahigh
# [28] rumen.rnalow         rumen.rnalow         rumen.rnalow
# [31] rumen.rnahigh        rumen.rnalow         rumen.rnahigh
# [34] rumen.rnahigh        rumen.rnahigh        rumen.rnalow
# [37] rumen.rnalow         rumen.rnalow         rumen.rnahigh
# 5 Levels: filtered.stool.day0 filtered.stool.day14 ... rumen.rnalow
# [1] 39
# [1] 5955   39
#                                          gpigfecal.dna.R496625_count
# Abiotrophia_defectiva                                       0.000000
# Abiotrophia_para-adiacens                                   0.000000
# Acanthamoeba_polyphaga_mimivirus                            1.224253
# Acanthocystis_turfacea_Chlorella_virus_1                    1.224253
# Acaricomes_phytoseiuli                                      3.224253
#                                          gpigfecal.dna.R496626_count
# Abiotrophia_defectiva                                       0.000000
# Abiotrophia_para-adiacens                                   0.000000
# Acanthamoeba_polyphaga_mimivirus                            0.000000
# Acanthocystis_turfacea_Chlorella_virus_1                    0.000000
# Acaricomes_phytoseiuli                                      2.022713
#                                          gpigfecal.dna.R496701_count
# Abiotrophia_defectiva                                              0
# Abiotrophia_para-adiacens                                          0
# Acanthamoeba_polyphaga_mimivirus                                   0
# Acanthocystis_turfacea_Chlorella_virus_1                           0
# Acaricomes_phytoseiuli                                             0
#                                          gpigfecal.dna.R496700_count
# Abiotrophia_defectiva                                       1.839255
# Abiotrophia_para-adiacens                                   0.000000
# Acanthamoeba_polyphaga_mimivirus                            0.000000
# Acanthocystis_turfacea_Chlorella_virus_1                    0.000000
# Acaricomes_phytoseiuli                                      4.424218
# Error in prcomp.default(t(acdmndfast), center = T, scale = T) :
#   cannot rescale a constant/zero column to unit variance

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # METAPHLAN2
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/metaphlan2.dir/*.mp2prof.tsv')
#
# m.classes <- c()
# mphlan <- matrix(0,0,0)
#
# getTable <- function(tblName){
#     out <- tryCatch(
#         {
#             tbl <- read.table(tblName,blank.lines.skip=T,sep="\t",row.names=1)
#             return(tbl)
#         },
#         error=function(cond){
#             return(FALSE)
#         },
#         warning=function(cond){
#             return(FALSE)
#         },
#         finally={
#
#         }
#     )
#     return(out)
# }
#
#
# for (tblName in tableNames){
#     print(tblName)
#     tbl <- getTable(tblName)
#     if(!tbl){
#         next
#     }
#
#
#     class <- tail(strsplit(strsplit(tblName,'-R')[[1]][1],'/')[[1]],1)
#     sample <- tail(strsplit(strsplit(tblName,'\\.mp2')[[1]][1],'/')[[1]],1)
#     genera <- rownames(tbl)[grep('g__',rownames(tbl))]
#     genera <- genera[grep('s__',genera,invert=T)]
#     tbl <-tbl[rownames(tbl) %in% genera,,drop=F]
#     m.classes <- c(m.classes,class)
#     newcolnames <- c(colnames(mphlan),sample)
#     mphlan <- merge(mphlan,tbl,by="row.names",all=T)
#     mphlan[is.na(mphlan)] <- 0
#     rownames(mphlan) <- mphlan[,1]
#     mphlan <- mphlan[,-1,drop=F]
#     colnames(mphlan) <- newcolnames
# }
# m.classes <- factor(m.classes)
# print(m.classes)
# print(mphlan[1:5,1:4])
#
# m.pca <- prcomp(t(mphlan),center=T,scale=T)
# plot(m.pca,type='l')
# Out:
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983262.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983263.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983264.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983265.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983266.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983267.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983268.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/cow_rumen/metaphlan2.dir/cowrumen-dna-R983269.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R495409.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496625.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496626.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496699.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496700.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496701.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496702.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/metaphlan2.dir/gpigfecal-dna-R496703.mp2prof.tsv"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/human_qin/metaphlan2.dir/human_qin-CD-R1.mp2prof.tsv"
#  [1] cowrumen-dna  cowrumen-dna  cowrumen-dna  cowrumen-dna  cowrumen-dna
#  [6] cowrumen-dna  cowrumen-dna  cowrumen-dna  gpigfecal-dna gpigfecal-dna
# [11] gpigfecal-dna gpigfecal-dna gpigfecal-dna gpigfecal-dna gpigfecal-dna
# [16] gpigfecal-dna
# Levels: cowrumen-dna gpigfecal-dna
#                                                                                                                               cowrumen-dna-R983262
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                         12.46866
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified              0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                  0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Nocardiopsaceae|g__Thermobifida                                      0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Bifidobacteriales|f__Bifidobacteriaceae|g__Bifidobacterium                              1.74867
#                                                                                                                               cowrumen-dna-R983263
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                         22.56221
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified              0.02308
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                  0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Nocardiopsaceae|g__Thermobifida                                      0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Bifidobacteriales|f__Bifidobacteriaceae|g__Bifidobacterium                              0.34512
#                                                                                                                               cowrumen-dna-R983264
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                          8.02903
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified              0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                  0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Nocardiopsaceae|g__Thermobifida                                      0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Bifidobacteriales|f__Bifidobacteriaceae|g__Bifidobacterium                              0.01385
#                                                                                                                               cowrumen-dna-R983265
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter                         47.32666
# k__Archaea|p__Euryarchaeota|c__Methanococci|o__Methanococcales|f__Methanocaldococcaceae|g__Methanocaldococcaceae_unclassified              0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Brevibacteriaceae|g__Brevibacterium                                  0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Nocardiopsaceae|g__Thermobifida                                      0.00000
# k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Bifidobacteriales|f__Bifidobacteriaceae|g__Bifidobacterium                              0.08591

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # AC-DIAMOND
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/*dmnd.dir/species.*dmnd.aggregated.counts.tsv.gz')
# print(tableNames)
# tableNames2 <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/*dmnd.dir/*dmnd.species.counts.tsv.gz')
# print(tableNames2)
#
# ad.classes <- c()
# acdmnd <- matrix(0,0,0)
# for (tbl in tableNames){
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     classesInTbl <- lapply(colnames(tbl),function(n){strsplit(n,'\\.R')[[1]][1]})
#
#     tbl[is.na(tbl)] <- 0
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     ad.classes <- c(ad.classes,  unlist(classesInTbl))
#
#     acdmnd <- merge(acdmnd,tbl,by="row.names",all=T)
#     acdmnd[is.na(acdmnd)] <- 0
#
#     rownames(acdmnd) <- acdmnd[,1]
#     acdmnd <- acdmnd[,-1]
# }
# ad.classes <- factor(ad.classes)
# print(ad.classes)
#
# print(length(ad.classes))
# print(dim(acdmnd))
# print(acdmnd[1:5,1:4])
#
# ad.pca <- prcomp(t(acdmnd),center=T,scale=T)
# plot(ad.pca,type='l')
# Out:
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/species.acdmnd.aggregated.counts.tsv.gz"
# [1] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R495409.acdmnd.species.counts.tsv.gz"
# [2] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496625.acdmnd.species.counts.tsv.gz"
# [3] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496626.acdmnd.species.counts.tsv.gz"
# [4] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496699.acdmnd.species.counts.tsv.gz"
# [5] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496700.acdmnd.species.counts.tsv.gz"
# [6] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496701.acdmnd.species.counts.tsv.gz"
# [7] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496702.acdmnd.species.counts.tsv.gz"
# [8] "/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/g_pig/acdmnd.dir/gpigfecal-dna-R496703.acdmnd.species.counts.tsv.gz"
# [1] gpigfecal.dna gpigfecal.dna gpigfecal.dna gpigfecal.dna gpigfecal.dna
# [6] gpigfecal.dna gpigfecal.dna gpigfecal.dna
# Levels: gpigfecal.dna
# [1] 8
# [1] 1477    8
#                               gpigfecal.dna.R496699_count
# Acaricomes_phytoseiuli                           4.330867
# Acaryochloris_marina                             7.389760
# Acetobacter_ghanensis                            0.000000
# Acetobacterium_psammolithicum                    0.000000
# Acetobacter_lovaniensis                          0.000000
#                               gpigfecal.dna.R496625_count
# Acaricomes_phytoseiuli                           3.649429
# Acaryochloris_marina                             6.649429
# Acetobacter_ghanensis                            0.000000
# Acetobacterium_psammolithicum                    0.000000
# Acetobacter_lovaniensis                          0.000000
#                               gpigfecal.dna.R496700_count
# Acaricomes_phytoseiuli                             3.4987
# Acaryochloris_marina                               7.4373
# Acetobacter_ghanensis                              0.0000
# Acetobacterium_psammolithicum                      0.0000
# Acetobacter_lovaniensis                            0.0000
#                               gpigfecal.dna.R496701_count
# Acaricomes_phytoseiuli                           2.971465
# Acaryochloris_marina                             7.778820
# Acetobacter_ghanensis                            0.000000
# Acetobacterium_psammolithicum                    0.000000
# Acetobacter_lovaniensis                          0.000000
# Error in prcomp.default(t(acdmnd), center = T, scale = T) :
#   cannot rescale a constant/zero column to unit variance

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # AC-DIAMOND FAST (ALTERNATE)
# #
# ##########################################################
# ##########################################################
#
# tableNames <- Sys.glob('/gfs/work/ddanko/taxonomic_profiler_comparison/analysis/actual/*/*dmndfast.dir/*dmndfast.species.counts.tsv.gz')
# print(tableNames)
#
# adf.classes <- c()
# acdmndfast <- matrix(0,0,0)
# for (tbl in tableNames){
#     print(tbl)
#     tbl <- read.table(tbl,header=T,blank.lines.skip=T,sep="\t",row.names=1)
#     print(head(tbl))
#     classesInTbl <- lapply(colnames(tbl),function(n){strsplit(n,'\\.R')[[1]][1]})
#
#     tbl[is.na(tbl)] <- 0
#     tbl <- data.matrix(tbl)
#     tbl <- sweep(tbl,2,colSums(tbl),function(el,n){ log2(1000000*el/n)})
#     tbl <- apply(tbl,1:2,max,0)
#     #tbl <- tbl[apply(tbl, 1, function(row) any(row !=0 )),]
#
#     ad.classes <- c(ad.classes,  unlist(classesInTbl))
#
#     acdmndfast <- merge(acdmndfast,tbl,by="row.names",all=T)
#     acdmndfast[is.na(acdmndfast)] <- 0
#
#     rownames(acdmndfast) <- acdmndfast[,1]
#     acdmndfast <- acdmndfast[,-1]
#     print('*')
# }
# adf.classes <- factor(adf.classes)
# print(adf.classes)
#
# print(length(adf.classes))
# print(dim(acdmndfast))
# print(acdmndfast[1:5,1:4])
#
# adf.pca <- prcomp(t(acdmndfast),center=T,scale=T)
# plot(adf.pca,type='l')

# %%
# %%R
# library(ggplot2)
#
# #pairs(adf.pca$x[,1:6],pch=21,bg=rainbow(length(unique(adf.classes)))[unclass(adf.classes)])
# pairs(adf.pca$x[,1:6],pch=21,col=adf.classes)

# %%
# %%R
#
# ##########################################################
# ##########################################################
# #
# # PCA Plots
# #
# ##########################################################
# ##########################################################
#
# library(ggplot2)
# library(gridExtra)
# library(factoextra)
#
# plotPCA <- function(comps, pca, classes){
#
#     df <- data.frame(pca$x)
#     df[,"class"] <- classes
#     combs <- combn(comps,2,simplify=F)
#
#     for (comb in combs){
#
#         p <- fviz_pca_ind(pca, axes=comb, geom = "point",
#                     habillage=classes, addEllipses=TRUE,
#                     ellipse.level= 0.95)+ theme_minimal()
#                 print(p)
#     }
# }

# %%
# %%R
#
# plotPCA(1:4, adf.pca, adf.classes)

# %%
# %%R
# plotPCA(1:4, k.pca, k.classes)

# %%
# %%R
#
# plotPCA(1:3, ad.pca, ad.classes)

# %%
# %%R
# plotPCA(1:3, m.pca, m.classes)
